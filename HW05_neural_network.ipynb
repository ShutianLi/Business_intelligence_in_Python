# %%
import pandas as pd 
data_link = '/Users/user/Desktop/Business_intelligence_in_Python/ToyotaCorolla.csv'
toyota_df = pd.read_csv(data_link,encoding = 'unicode_escape')

# %%
toyota_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 39 columns):
# Id                   1436 non-null int64
# Model                1436 non-null object
# Price                1436 non-null int64
# Age_08_04            1436 non-null int64
# Mfg_Month            1436 non-null int64
# Mfg_Year             1436 non-null int64
# KM                   1436 non-null int64
# Fuel_Type            1436 non-null object
# HP                   1436 non-null int64
# Met_Color            1436 non-null int64
# Color                1436 non-null object
# Automatic            1436 non-null int64
# CC                   1436 non-null int64
# Doors                1436 non-null int64
# Cylinders            1436 non-null int64
# Gears                1436 non-null int64
# Quarterly_Tax        1436 non-null int64
# Weight               1436 non-null int64
# Mfr_Guarantee        1436 non-null int64
# BOVAG_Guarantee      1436 non-null int64
# ...

# %%
toyota_df.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1436.000000   1436.000000  1436.000000  1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075     5.548747  1999.625348
# std     416.476890   3626.964585    18.599988     3.354085     1.540722
# min       1.000000   4350.000000     1.000000     1.000000  1998.000000
# 25%     361.750000   8450.000000    44.000000     3.000000  1998.000000
# 50%     721.500000   9900.000000    61.000000     5.000000  1999.000000
# 75%    1081.250000  11950.000000    70.000000     8.000000  2001.000000
# max    1442.000000  32500.000000    80.000000    12.000000  2004.000000
#
#                   KM           HP    Met_Color    Automatic           CC  ...  \
# count    1436.000000  1436.000000  1436.000000  1436.000000   1436.00000  ...
# mean    68533.259749   101.502089     0.674791     0.055710   1576.85585  ...
# std     37506.448872    14.981080     0.468616     0.229441    424.38677  ...
# ...

# %%
#Preprocess 
toyota_df.loc[toyota_df.Fuel_Type=='CNG','Fuel_Type_CNG']=1
toyota_df.loc[toyota_df.Fuel_Type_CNG.isnull(),'Fuel_Type_CNG']=0

toyota_df.loc[toyota_df.Fuel_Type=='Diesel','Fuel_Type_Diesel']=1
toyota_df.loc[toyota_df.Fuel_Type_Diesel.isnull(),'Fuel_Type_Diesel']=0

# %%
toyota_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 41 columns):
# Id                   1436 non-null int64
# Model                1436 non-null object
# Price                1436 non-null int64
# Age_08_04            1436 non-null int64
# Mfg_Month            1436 non-null int64
# Mfg_Year             1436 non-null int64
# KM                   1436 non-null int64
# Fuel_Type            1436 non-null object
# HP                   1436 non-null int64
# Met_Color            1436 non-null int64
# Color                1436 non-null object
# Automatic            1436 non-null int64
# CC                   1436 non-null int64
# Doors                1436 non-null int64
# Cylinders            1436 non-null int64
# Gears                1436 non-null int64
# Quarterly_Tax        1436 non-null int64
# Weight               1436 non-null int64
# Mfr_Guarantee        1436 non-null int64
# BOVAG_Guarantee      1436 non-null int64
# ...

# %%
#partition data 
from sklearn.model_selection import train_test_split
X = toyota_df[['Age_08_04','KM','Fuel_Type_CNG','Fuel_Type_Diesel','HP','Automatic','Doors','Quarterly_Tax' ,'Mfr_Guarantee','Guarantee_Period', 
                  'Airco', 'Automatic_airco','CD_Player','Powered_Windows','Sport_Model','Tow_Bar']] # which is the predictors 
y = toyota_df[['Price']] #which is the target variables

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 16 columns):
# Age_08_04           1436 non-null int64
# KM                  1436 non-null int64
# Fuel_Type_CNG       1436 non-null float64
# Fuel_Type_Diesel    1436 non-null float64
# HP                  1436 non-null int64
# Automatic           1436 non-null int64
# Doors               1436 non-null int64
# Quarterly_Tax       1436 non-null int64
# Mfr_Guarantee       1436 non-null int64
# Guarantee_Period    1436 non-null int64
# Airco               1436 non-null int64
# Automatic_airco     1436 non-null int64
# CD_Player           1436 non-null int64
# Powered_Windows     1436 non-null int64
# Sport_Model         1436 non-null int64
# Tow_Bar             1436 non-null int64
# dtypes: float64(2), int64(14)
# memory usage: 179.6 KB

# %%
y.head()
# Out:
#    Price
# 0  13500
# 1  13750
# 2  13950
# 3  14950
# 4  13750

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,train_size=0.4,random_state=12345)

# %%
X_train.head()
# Out:
#       Age_08_04     KM  Fuel_Type_CNG  Fuel_Type_Diesel   HP  Automatic  \
# 147          13  19988            0.0               0.0  110          0
# 1032         60  28500            0.0               0.0  110          0
# 555          50  40400            0.0               0.0   97          0
# 784          61  75609            0.0               0.0   86          0
# 722          57  88480            0.0               0.0  110          0
#
#       Doors  Quarterly_Tax  Mfr_Guarantee  Guarantee_Period  Airco  \
# 147       5             85              1                 3      1
# 1032      5             85              0                 3      1
# 555       5             85              1                 3      0
# 784       3             69              1                 3      0
# 722       3             69              1                 3      1
#
#       Automatic_airco  CD_Player  Powered_Windows  Sport_Model  Tow_Bar
# ...

# %%
#preprocess 
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train_scale=sc_X.fit_transform(X_train)
X_test_scale=sc_X.transform(X_test)

sc_y= StandardScaler()
y_train_scale = sc_y.fit_transform(y_train)
y_test_scale = sc_y.transform(y_test)

# %%
from sklearn.neural_network import MLPRegressor

# %%
model_mlp_1 = MLPRegressor(hidden_layer_sizes = 3, activation='relu',random_state = 12345, max_iter = 3000)

# %%
model_fit_1 = model_mlp_1.fit(X_train_scale,y_train_scale.ravel())

# %%
y_pred_1=model_fit.predict(X_test_scale)

# %%
y_pred_1
# Out:
# array([-7.36213694e-01,  5.23600086e-01,  4.74599721e-01, -6.51499468e-01,
#         3.64069023e-01, -6.85550530e-01, -2.03223398e-01,  1.94874215e+00,
#         6.65839003e-01, -5.92025928e-01, -2.31791396e-01,  7.71637675e-01,
#        -5.48212495e-01, -1.58909554e-01,  2.65901673e-02,  6.71532892e-01,
#        -6.06618910e-01,  3.13374263e+00, -3.28866828e-01,  1.17358927e+00,
#         4.56368022e-02, -1.05208513e+00, -2.28907365e-01, -6.06450003e-01,
#        -4.86054566e-01, -6.75832730e-01,  1.70946926e+00, -4.05572933e-01,
#         9.44481090e-01,  1.08094748e+00, -3.31711610e-01, -5.03910869e-01,
#        -4.96969152e-01,  1.07369825e+00,  2.82564878e+00,  1.04553866e-01,
#        -8.20465562e-01, -2.36718946e-01, -8.85641332e-01, -4.39323186e-01,
#        -2.30103650e-01, -4.59360129e-01, -4.82661898e-02,  4.56901917e+00,
#        -2.45706801e-01, -5.46807386e-01,  2.69844995e-01, -8.42773044e-01,
# ...

# %%
result_df = pd.DataFrame({'predict':y_pred_1,'actual':y_test_scale.ravel()})

# %%
result_df.head()
# Out:
#     predict    actual
# 0 -0.736214 -1.306155
# 1  0.523600  0.624698
# 2  0.474600 -0.326937
# 3 -0.651499 -0.809650
# 4  0.364069  0.348862

# %%
import numpy as np 
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_absolute_error
 
MSE_1 = mean_squared_error(result_df[['actual']],result_df[['predict']])

print('MSE is ：',MSE)
print('RMSE is ：',np.sqrt(MSE))
# Out:
# MSE is ： 0.11873270580095498
# RMSE is ： 0.3445761248272361

# %%
## neuralnetwork 2 
model_mlp_2 = MLPRegressor(hidden_layer_sizes = (5,5), activation='relu',random_state = 12345, max_iter = 3000)

# %%
model_fit_2 = model_mlp_2.fit(X_train_scale,y_train_scale.ravel())

# %%
y_pred_2 =model_fit_2.predict(X_test_scale)

# %%
result2_df = pd.DataFrame({'predict':y_pred_2,'actual':y_test_scale.ravel()})

# %%
result2_df.head()
# Out:
#     predict    actual
# 0 -0.880250 -1.306155
# 1  0.322091  0.624698
# 2 -0.146753 -0.326937
# 3 -0.257606 -0.809650
# 4  0.151215  0.348862

# %%
MSE_2 = mean_squared_error(result2_df[['actual']],result2_df[['predict']])

print('MSE is ：',MSE_2)
print('RMSE is ：',np.sqrt(MSE_2))
# Out:
# MSE is ： 0.1304737110567339
# RMSE is ： 0.36121144923262594
